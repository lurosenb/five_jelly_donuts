# %%
from py_edamam import Edamam
import json
with open('api_keys.json') as f:
    keys = json.load(f)

e = Edamam(nutrition_appid=keys['nutrition_appid'],
    nutrition_appkey=keys['nutrition_appkey'],
    food_appid=keys['food_appid'],
    food_appkey=keys['food_appkey'])
           
food = e.search_nutrient("2 chicken tenders")

# %%
food
# Out:
# {'uri': 'http://www.edamam.com/ontologies/edamam.owl#recipe_6250411f3af24007b652d2c766b5aa39',
#  'yield': 4.0,
#  'calories': 794,
#  'totalWeight': 302.0,
#  'dietLabels': [],
#  'healthLabels': ['SUGAR_CONSCIOUS',
#   'KIDNEY_FRIENDLY',
#   'PALEO',
#   'SPECIFIC_CARBS',
#   'DASH',
#   'DAIRY_FREE',
#   'GLUTEN_FREE',
#   'WHEAT_FREE',
#   'EGG_FREE',
#   'MILK_FREE',
#   'PEANUT_FREE',
#   'TREE_NUT_FREE',
#   'SOY_FREE',
#   'FISH_FREE',
#   'SHELLFISH_FREE',
#   'PORK_FREE',
#   'RED_MEAT_FREE',
#   'CRUSTACEAN_FREE',
#   'CELERY_FREE',
#   'MUSTARD_FREE',
#   'SESAME_FREE',
#   'LUPINE_FREE',
#   'MOLLUSK_FREE',
#   'ALCOHOL_FREE',
#   'NO_OIL_ADDED',
#   'NO_SUGAR_ADDED',
#   'SULPHITE_FREE',
#   'FODMAP_FREE'],
#  'cautions': ['FODMAP'],
#  'totalNutrients': {'ENERC_KCAL': {'label': 'Energy',
#    'quantity': 794.26,
#    'unit': 'kcal'},
#   'FAT': {'label': 'Total lipid (fat)', 'quantity': 47.565, 'unit': 'g'},
#   'FASAT': {'label': 'Fatty acids, total saturated',
#    'quantity': 9.8452,
#    'unit': 'g'},
#   'FAMS': {'label': 'Fatty acids, total monounsaturated',
#    'quantity': 19.5696,
#    'unit': 'g'},
#   'FAPU': {'label': 'Fatty acids, total polyunsaturated',
#    'quantity': 10.0868,
#    'unit': 'g'},
#   'CHOCDF': {'label': 'Carbohydrate, by difference',
#    'quantity': 45.3302,
#    'unit': 'g'},
#   'CHOCDF.net': {'label': 'Carbohydrates (net)',
#    'quantity': 42.008199999999995,
#    'unit': 'g'},
#   'FIBTG': {'label': 'Fiber, total dietary',
#    'quantity': 3.3220000000000005,
#    'unit': 'g'},
#   'SUGAR': {'label': 'Sugars, total', 'quantity': 1.1174, 'unit': 'g'},
#   'PROCNT': {'label': 'Protein', 'quantity': 44.4846, 'unit': 'g'},
#   'CHOLE': {'label': 'Cholesterol',
#    'quantity': 123.82000000000001,
#    'unit': 'mg'},
#   'NA': {'label': 'Sodium, Na', 'quantity': 1362.02, 'unit': 'mg'},
#   'CA': {'label': 'Calcium, Ca', 'quantity': 57.38, 'unit': 'mg'},
#   'MG': {'label': 'Magnesium, Mg', 'quantity': 69.46, 'unit': 'mg'},
#   'K': {'label': 'Potassium, K', 'quantity': 646.28, 'unit': 'mg'},
#   'FE': {'label': 'Iron, Fe', 'quantity': 3.3522000000000003, 'unit': 'mg'},
#   'ZN': {'label': 'Zinc, Zn', 'quantity': 2.3556, 'unit': 'mg'},
#   'P': {'label': 'Phosphorus, P', 'quantity': 637.22, 'unit': 'mg'},
#   'VITC': {'label': 'Vitamin C, total ascorbic acid',
#    'quantity': 2.4160000000000004,
#    'unit': 'mg'},
#   'THIA': {'label': 'Thiamin', 'quantity': 0.6342, 'unit': 'mg'},
#   'RIBF': {'label': 'Riboflavin', 'quantity': 0.2718, 'unit': 'mg'},
#   'NIA': {'label': 'Niacin', 'quantity': 17.2442, 'unit': 'mg'},
#   'VITB6A': {'label': 'Vitamin B-6', 'quantity': 0.1208, 'unit': 'mg'},
#   'FOLDFE': {'label': 'Folate, DFE', 'quantity': 36.24, 'unit': 'µg'},
#   'FOLFD': {'label': 'Folate, food', 'quantity': 36.24, 'unit': 'µg'},
#   'VITB12': {'label': 'Vitamin B-12', 'quantity': 0.8154, 'unit': 'µg'},
#   'VITD': {'label': 'Vitamin D (D2 + D3)',
#    'quantity': 0.6040000000000001,
#    'unit': 'µg'},
#   'TOCPHA': {'label': 'Vitamin E (alpha-tocopherol)',
#    'quantity': 0.2416,
#    'unit': 'mg'},
#   'VITK1': {'label': 'Vitamin K (phylloquinone)',
#    'quantity': 44.394,
#    'unit': 'µg'},
#   'WATER': {'label': 'Water', 'quantity': 159.2748, 'unit': 'g'}},
#  'totalDaily': {'ENERC_KCAL': {'label': 'Energy',
#    'quantity': 39.713,
#    'unit': '%'},
#   'FAT': {'label': 'Fat', 'quantity': 73.17692307692307, 'unit': '%'},
#   'FASAT': {'label': 'Saturated', 'quantity': 49.226, 'unit': '%'},
#   'CHOCDF': {'label': 'Carbs', 'quantity': 15.110066666666665, 'unit': '%'},
#   'FIBTG': {'label': 'Fiber', 'quantity': 13.288000000000002, 'unit': '%'},
#   'PROCNT': {'label': 'Protein', 'quantity': 88.9692, 'unit': '%'},
#   'CHOLE': {'label': 'Cholesterol',
#    'quantity': 41.27333333333333,
#    'unit': '%'},
#   'NA': {'label': 'Sodium', 'quantity': 56.75083333333333, 'unit': '%'},
#   'CA': {'label': 'Calcium', 'quantity': 5.738, 'unit': '%'},
#   'MG': {'label': 'Magnesium', 'quantity': 16.538095238095234, 'unit': '%'},
#   'K': {'label': 'Potassium', 'quantity': 13.75063829787234, 'unit': '%'},
#   'FE': {'label': 'Iron', 'quantity': 18.623333333333335, 'unit': '%'},
#   'ZN': {'label': 'Zinc', 'quantity': 21.414545454545454, 'unit': '%'},
#   'P': {'label': 'Phosphorus', 'quantity': 91.03142857142858, 'unit': '%'},
#   'VITC': {'label': 'Vitamin C', 'quantity': 2.684444444444445, 'unit': '%'},
#   'THIA': {'label': 'Thiamin (B1)', 'quantity': 52.85, 'unit': '%'},
#   'RIBF': {'label': 'Riboflavin (B2)',
#    'quantity': 20.907692307692308,
#    'unit': '%'},
#   'NIA': {'label': 'Niacin (B3)', 'quantity': 107.77624999999999, 'unit': '%'},
#   'VITB6A': {'label': 'Vitamin B6',
#    'quantity': 9.292307692307691,
#    'unit': '%'},
#   'FOLDFE': {'label': 'Folate equivalent (total)',
#    'quantity': 9.06,
#    'unit': '%'},
#   'VITB12': {'label': 'Vitamin B12', 'quantity': 33.975, 'unit': '%'},
#   'VITD': {'label': 'Vitamin D', 'quantity': 4.026666666666667, 'unit': '%'},
#   'TOCPHA': {'label': 'Vitamin E',
#    'quantity': 1.6106666666666667,
#    'unit': '%'},
#   'VITK1': {'label': 'Vitamin K', 'quantity': 36.995, 'unit': '%'}},
#  'ingredients': [{'text': '2 chicken tenders',
#    'parsed': [{'quantity': 2.0,
#      'measure': 'whole',
#      'foodMatch': 'chicken tenders',
#      'food': 'chicken tenders',
#      'foodId': 'food_bdc1hahbi6pzj2bjr99mzbq7v4dm',
#      'weight': 302.0,
#      'retainedWeight': 302.0,
#      'nutrients': {'RIBF': {'label': 'Riboflavin',
#        'quantity': 0.2718,
#        'unit': 'mg'},
#       'VITD': {'label': 'Vitamin D', 'quantity': 27.18, 'unit': 'IU'},
#       'THIA': {'label': 'Thiamin', 'quantity': 0.6342, 'unit': 'mg'},
#       'FAPU': {'label': 'Fatty acids, total polyunsaturated',
#        'quantity': 10.0868,
#        'unit': 'g'},
#       'NIA': {'label': 'Niacin', 'quantity': 17.2442, 'unit': 'mg'},
#       'ENERC_KCAL': {'label': 'Energy', 'quantity': 794.26, 'unit': 'kcal'},
#       'FASAT': {'label': 'Fatty acids, total saturated',
#        'quantity': 9.8452,
#        'unit': 'g'},
#       'VITC': {'label': 'Vitamin C, total ascorbic acid',
#        'quantity': 2.4160000000000004,
#        'unit': 'mg'},
#       'PROCNT': {'label': 'Protein', 'quantity': 44.4846, 'unit': 'g'},
#       'TOCPHA': {'label': 'Vitamin E (alpha-tocopherol)',
#        'quantity': 0.2416,
#        'unit': 'mg'},
#       'CHOLE': {'label': 'Cholesterol', 'quantity': 123.82, 'unit': 'mg'},
#       'FAMS': {'label': 'Fatty acids, total monounsaturated',
#        'quantity': 19.5696,
#        'unit': 'g'},
#       'CHOCDF': {'label': 'Carbohydrate, by difference',
#        'quantity': 45.3302,
#        'unit': 'g'},
#       'FAT': {'label': 'Total lipid (fat)', 'quantity': 47.565, 'unit': 'g'},
#       'VITB6A': {'label': 'Vitamin B-6', 'quantity': 0.1208, 'unit': 'mg'},
#       'VITB12': {'label': 'Vitamin B-12', 'quantity': 0.8154, 'unit': 'µg'},
#       'FIBTG': {'label': 'Fiber, total dietary',
#        'quantity': 3.3220000000000005,
#        'unit': 'g'},
#       'WATER': {'label': 'Water', 'quantity': 159.27480000000003, 'unit': 'g'},
#       'K': {'label': 'Potassium, K', 'quantity': 646.28, 'unit': 'mg'},
#       'P': {'label': 'Phosphorus, P', 'quantity': 637.22, 'unit': 'mg'},
#       'NA': {'label': 'Sodium, Na', 'quantity': 1362.02, 'unit': 'mg'},
#       'ZN': {'label': 'Zinc, Zn', 'quantity': 2.3556, 'unit': 'mg'},
#       'SUGAR': {'label': 'Sugars, total', 'quantity': 1.1174, 'unit': 'g'},
#       'CA': {'label': 'Calcium, Ca', 'quantity': 57.38, 'unit': 'mg'},
#       'MG': {'label': 'Magnesium, Mg', 'quantity': 69.46, 'unit': 'mg'},
#       'FE': {'label': 'Iron, Fe',
#        'quantity': 3.3522000000000003,
#        'unit': 'mg'},
#       'VITK1': {'label': 'Vitamin K (phylloquinone)',
#        'quantity': 44.394,
#        'unit': 'µg'},
#       'FOLFD': {'label': 'Folate, food', 'quantity': 36.24, 'unit': 'µg'},
#       'FOLDFE': {'label': 'Folate, DFE', 'quantity': 36.24, 'unit': 'µg'}},
#      'measureURI': 'http://www.edamam.com/ontologies/edamam.owl#Measure_unit',
#      'status': 'OK'}]}],
#  'totalNutrientsKCal': {'ENERC_KCAL': {'label': 'Energy',
#    'quantity': 795,
#    'unit': 'kcal'},
#   'PROCNT_KCAL': {'label': 'Calories from protein',
#    'quantity': 180,
#    'unit': 'kcal'},
#   'FAT_KCAL': {'label': 'Calories from fat', 'quantity': 432, 'unit': 'kcal'},
#   'CHOCDF_KCAL': {'label': 'Calories from carbohydrates',
#    'quantity': 183,
#    'unit': 'kcal'}}}
