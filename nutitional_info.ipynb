# %%
from py_edamam import Edamam
import json
with open('api_keys.json') as f:
    keys = json.load(f)

e = Edamam(nutrition_appid=keys['nutrition_appid'],
    nutrition_appkey=keys['nutrition_appkey'],
    food_appid=keys['food_appid'],
    food_appkey=keys['food_appkey'])
           
food = e.search_nutrient("1 bowl of frosted flakes with milk")

# %%
food
# Out:
# {'uri': 'http://www.edamam.com/ontologies/edamam.owl#recipe_d71e28cb7ac246afb1ff913c55e27659',
#  'yield': 2.0,
#  'calories': 295,
#  'totalWeight': 80.0,
#  'dietLabels': ['LOW_FAT'],
#  'healthLabels': ['LOW_FAT_ABS',
#   'LOW_POTASSIUM',
#   'KIDNEY_FRIENDLY',
#   'VEGETARIAN',
#   'PESCATARIAN',
#   'EGG_FREE',
#   'PEANUT_FREE',
#   'TREE_NUT_FREE',
#   'SOY_FREE',
#   'FISH_FREE',
#   'SHELLFISH_FREE',
#   'PORK_FREE',
#   'RED_MEAT_FREE',
#   'CRUSTACEAN_FREE',
#   'CELERY_FREE',
#   'MUSTARD_FREE',
#   'SESAME_FREE',
#   'LUPINE_FREE',
#   'MOLLUSK_FREE',
#   'ALCOHOL_FREE',
#   'NO_OIL_ADDED',
#   'SULPHITE_FREE',
#   'KOSHER'],
#  'cautions': ['SULFITES'],
#  'totalNutrients': {'ENERC_KCAL': {'label': 'Energy',
#    'quantity': 295.2,
#    'unit': 'kcal'},
#   'FAT': {'label': 'Total lipid (fat)', 'quantity': 1.344, 'unit': 'g'},
#   'FASAT': {'label': 'Fatty acids, total saturated',
#    'quantity': 0.3608,
#    'unit': 'g'},
# ...
