# %%
from stable_baselines3 import PPO, DQN, A2C, SAC
import numpy as np
import pandas as pd
from meal_planning_environment import MaxNutritionEnv, HeuristicEnv, GPTOnlyEnv, RLHFEnv
from meal_planning_environment import run_with_learning_algorithm
from dietkit import load_ingredient, load_menu, load_diet

import os 
import time
import sqlite3

# %% [markdown]
# ## Initialize dietkit

# %%
all_ingredients = load_ingredient(sample_language = 'eng')
meal_dict = load_menu(ingredients = all_ingredients, sample_language = 'eng')
example_mealplans = load_diet(menus = meal_dict, num_loads = 100, sample_language = 'eng', sample_name = 'ML')

possible_meals = np.array(list(meal_dict.keys()))
meal_categories = np.array([meal.category if isinstance(meal.category, str) else meal.category[0] for meal in meal_dict.values()])
nutrition_data = pd.DataFrame([meal.nutrition for meal in meal_dict.values()], index=possible_meals)

display(possible_meals)
display(nutrition_data)
# Out:
# array(['S watermelon punch (without milks)', 'Dried persimmon',
#        'S kyogo grape (100g)', ..., 'Green onion kimchi',
#        'Pickled paprika', 'empty'], dtype='<U72')
#                                     Energy  Protein      Fat  Carbohydrate  \
# S watermelon punch (without milks)   55.00   0.7900  0.05000       13.8180
# Dried persimmon                      76.50   0.5820  0.04800       20.5830
# S kyogo grape (100g)                 61.00   0.4300  0.04000       16.3800
# S dried persimmon                    85.60   0.7720  0.03200       22.9800
# S fruit punch                       101.05   3.6700  3.36450       14.8900
# ...                                    ...      ...      ...           ...
# Ponytail radish kimchi               10.25   0.5050  0.05000        1.9725
# Kohlrabi watery kimchi                5.50   0.2900  0.01250        1.2900
# Green onion kimchi                   12.25   0.6250  0.14500        2.1275
# Pickled paprika                       7.94   0.2017  0.03005        1.9859
# empty                                 0.00   0.0000  0.00000        0.0000
#
#                                     Total Dietary  Calcium     Iron   Sodium  \
# S watermelon punch (without milks)          0.200    7.200  0.18600    0.600
# Dried persimmon                             3.360    6.300  0.19200    0.900
# S kyogo grape (100g)                        0.400    4.000  0.17000    1.000
# S dried persimmon                           3.400    5.600  0.24800    0.400
# S fruit punch                               0.790  117.650  0.19850   36.000
# ...                                           ...      ...      ...      ...
# Ponytail radish kimchi                      0.775   10.500  0.16750  173.000
# Kohlrabi watery kimchi                      0.600   10.500  0.06750    1.750
# Green onion kimchi                          1.150   15.000  0.18250  163.750
# Pickled paprika                             0.348    1.675  0.08145   67.204
# empty                                       0.000    0.000  0.00000    0.000
#
#                                     Vitamin A  Vitamin B1 (Thiamine)  \
# S watermelon punch (without milks)  71.083333               0.024000
# Dried persimmon                     13.725000               0.003000
# S kyogo grape (100g)                 2.166667               0.026000
# S dried persimmon                    9.533333               0.003600
# S fruit punch                       91.166667               0.040350
# ...                                       ...                    ...
# Ponytail radish kimchi               5.541667               0.003250
# Kohlrabi watery kimchi               0.250000               0.203750
# Green onion kimchi                  26.854167               0.012750
# Pickled paprika                      4.850000               0.003675
# empty                                0.000000               0.000000
#
#                                     Vitamin B2 (Rivoflavin)  Vitamin C  \
# S watermelon punch (without milks)                  0.03000     0.0000
# Dried persimmon                                     0.06720     1.5330
# S kyogo grape (100g)                                0.04700     0.1300
# S dried persimmon                                   0.09720     1.0680
# S fruit punch                                       0.19110     1.8925
# ...                                                     ...        ...
# Ponytail radish kimchi                              0.01900     0.4125
# Kohlrabi watery kimchi                              0.00875     0.0000
# Green onion kimchi                                  0.02850     0.5550
# Pickled paprika                                     0.02709    24.2820
# empty                                               0.00000     0.0000
#
#                                     Linoleic Acid  Alpha-Linolenic Acid
# S watermelon punch (without milks)        14.2500                2.9300
# Dried persimmon                            0.0000                8.6010
# S kyogo grape (100g)                      11.8900                6.0900
# S dried persimmon                          0.0000                5.0440
# S fruit punch                             86.6605               10.6925
# ...                                           ...                   ...
# Ponytail radish kimchi                    19.7050                9.4775
# Kohlrabi watery kimchi                     1.9650                5.1100
# Green onion kimchi                        79.8050               17.1425
# Pickled paprika                           12.4483                6.5448
# empty                                      0.0000                0.0000
#
# [3235 rows x 14 columns]

# %%
nutrition_data.loc['Spring cabbage soy paste soup']
# Out:
# Energy                      37.164000
# Protein                      4.096990
# Fat                          1.199610
# Carbohydrate                 2.785950
# Total Dietary                1.423900
# Calcium                     87.674000
# Iron                         1.038960
# Sodium                     208.536000
# Vitamin A                   23.496250
# Vitamin B1 (Thiamine)        0.047344
# Vitamin B2 (Rivoflavin)      0.075938
# Vitamin C                    7.072830
# Linoleic Acid              483.542490
# Alpha-Linolenic Acid       105.884650
# Name: Spring cabbage soy paste soup, dtype: float64

# %% [markdown]
# ## TODO: remove

# %% [markdown]
# # Load carbon impact data

# %%
sql_conn = sqlite3.connect('carbon_impacts.db')
carbon_impacts_df = pd.read_sql_query("SELECT * FROM carbon_impacts", sql_conn)
carbon_impacts_df['meal'] = carbon_impacts_df['meal'].str.replace('Menu object: ', '')
display(carbon_impacts_df)
carbon_data = dict(zip(carbon_impacts_df.meal, carbon_impacts_df.impact))
# Out:
#                                     meal    impact  \
# 0                        Dried persimmon  8.000000
# 1     S watermelon punch (without milks) -0.333333
# 2                   S kyogo grape (100g)  4.000000
# 3                      S dried persimmon  7.000000
# 4                          S fruit punch -2.666667
# ...                                  ...       ...
# 3230              Ponytail radish kimchi  4.000000
# 3231              Kohlrabi watery kimchi  5.333333
# 3232                  Green onion kimchi  3.333333
# 3233                     Pickled paprika  5.000000
# 3234                               empty  0.000000
#
#                                             explanation
# 0     The carbon impact score is 9. Drying persimmon...
# 1     The carbon impact score is -5. \n\nCarbonated ...
# 2     The carbon impact score is 6. Grapes have a re...
# 3     The carbon impact score is 7. Dried persimmon ...
# 4     The carbon impact score is -5. \n\nThis meal c...
# ...                                                 ...
# 3230  The carbon impact score is 3. \n\nKimchi is ty...
# 3231  The carbon impact score is 5. Kohlrabi is a lo...
# 3232  The carbon impact score is 2. \n\nKimchi and P...
# 3233  The carbon impact score is 8. This meal has a ...
# 3234  I am sorry, but I cannot rate a proposed meal ...
#
# [3235 rows x 3 columns]

# %% [markdown]
# ## Initialize MealPlanningEnv
# Initialize each of the following environments:
# 1. MaxNutritionEnv
# 1. MaxNutritionCompositionEnv
# 2. HeuristicEnv
# 3. GPTOnlyEnv
# 4. RLHFEnv

# %% [markdown]
# Descriptions to write
# -   Explaining the custom gym environment
#     -   States, actions, observations, reward, agent
# -   Explaining the custom random agent
# -   Explaining the dataset
# -   Explaining the heursitic reward function and nutrition values
# -   Explaining the GPT warmup setup (RL"H"F)
#
# Code to run/implement
# -   Lucius (1 notebook): Demonstrating that the environment works (<PPO, DQN, A2C> + max nutrition reward)
# -   Lucius (1 notebook): Demonstrating a better reward function (PPO + heuristic reward nutrition only)
# -   Lucius (1 notebook): Demonstrating a better reward function (PPO + heuristic reward with some entropy/repetition)
# -   Lucius (1 notebook): Demonstrating a better reward function (PPO + heuristic reward with (maybe entropy/repetition) + carbon impact)
# -   Compare different algorithms for heuristic reward
# -   Lucas (1 notebook): Compare different algorithms for GPT reward
# -   Implement carbon impact in heuristic environment.
# -   Lucas (functions/class in .py): Implement a new `plot_learning_curve()` function that takes in multiple directories and plots one learning curve with method labels.
# -   Lucas (class in .py): Implement a random agent using `stable_baselines.common.base_class.BaseRLModel`.
#
# Story
# -   We define the problem and setup the environment.
# -   We start with something bad (max nutrition) and show that it works.
# -   We realize that the most challenging part of this is defining reward.
# -   We improve the reward function and show that it works better.
# -   We realize another challenging part is composition. We customize the reward function further to incorporate composition.
#     -   This is very challenging.
# -   We also care about the environment. So we incoporate carbon impact to our reward.
#
# -   Why did we frame this as a full sequential RL problem?
#     -   We thought about a contextual bandit, but: (1) each state depends a lot on past states in a diet (breaks independence assumption), so we didn't think it was a natural fit.
# -   Which algorithms and why? (at least two of these should have explanations that connect to the plots, eg. PPO vs. DQN)
#     - PPO:
#     - A2C:
#     - DQN:
#     - SAC:
#     - TD3:

# %%
num_meals = 21
gpt_env = GPTOnlyEnv(possible_meals=possible_meals, meal_categories=meal_categories, nutrition_data=nutrition_data, carbon_data=carbon_data, num_meals=num_meals)

# %%
log_dir = f"./tmp/gym/{time.strftime('%Y%m%d-%H%M%S')}"
os.makedirs(log_dir, exist_ok=False)
print(f'Output stored at: {log_dir}')

gpt_env.set_reward_weights(
    coef_nutrition_lower=1,
    coef_nutrition_upper=-1,
    coef_sequence_entropy=0,
    coef_repetitions=0,
    coef_overall_entropy=0,
    coef_carbon=3
)
run_with_learning_algorithm(PPO, gpt_env, 12000, log_dir, num_meals=21, seed=1, n_eval_episodes=10, num_episodes=10)

# %%
num_meals = 21
gpt_env = GPTOnlyEnv(possible_meals=possible_meals, meal_categories=meal_categories, nutrition_data=nutrition_data, carbon_data=carbon_data, num_meals=num_meals)

# %%
log_dir = f"./tmp/gym/{time.strftime('%Y%m%d-%H%M%S')}"
os.makedirs(log_dir, exist_ok=False)
print(f'Output stored at: {log_dir}')

gpt_env.set_reward_weights(
    coef_nutrition_lower=1,
    coef_nutrition_upper=-1,
    coef_sequence_entropy=0,
    coef_repetitions=0,
    coef_overall_entropy=0,
    coef_carbon=3
)
run_with_learning_algorithm(A2C, gpt_env, 12000, log_dir, num_meals=21, seed=0, n_eval_episodes=10, num_episodes=10)
# Out:
# Output stored at: ./tmp/gym/20230425-135709
# Using cpu device
# Wrapping the env in a DummyVecEnv.
# Initial Results
# I am a 6ft tall 25 year old male, 168 pounds. I am very active. Please rate the following proposed meal plan on a scale of 1-10, where 1 is an unhealthy or unnatural meal plan and 10 is a perfect, balanced healthy meal plan:
# Meal 0: Seasoned salad with cabbage in soy paste (Energy: 22.115000000000002, Protein: 0.89915, Fat: 0.41678000000000004, Carbohydrate: 4.28053, Total Dietary: 0.9774999999999999, Calcium: 20.221999999999998, Iron: 0.2896000000000001, Sodium: 102.672, Vitamin A: 0.6118333331839999, Vitamin B1 (Thiamine): 0.029720000000000003, Vitamin B2 (Rivoflavin): 0.02663, Vitamin C: 6.940799999999999, Linoleic Acid: 89.44575, Alpha-Linolenic Acid: 11.951039999999999, )
# Please begin by phrasing your numeric answer as: "The meal plan is a X out of 10" and then explaining your rating.
#
# The meal plan is a 7 out of 10. The seasoned salad with cabbage and soy paste is a good option as it provides a decent amount of fiber, vitamins, and minerals. It is lower in protein and fat, but that can be balanced out by incorporating protein and healthy fat sources in other meals throughout the day. However, without knowing the portion size and the meals for the rest of the day, it is difficult to make a complete judgment on the overall healthfulness and balance of this meal plan.
# I am a 6ft tall 25 year old male, 168 pounds. I am very active. Please rate the following proposed meal plan on a scale of 1-10, where 1 is an unhealthy or unnatural meal plan and 10 is a perfect, balanced healthy meal plan:
# Meal 0: Seasoned salad with cabbage in soy paste (Energy: 22.115000000000002, Protein: 0.89915, Fat: 0.41678000000000004, Carbohydrate: 4.28053, Total Dietary: 0.9774999999999999, Calcium: 20.221999999999998, Iron: 0.2896000000000001, Sodium: 102.672, Vitamin A: 0.6118333331839999, Vitamin B1 (Thiamine): 0.029720000000000003, Vitamin B2 (Rivoflavin): 0.02663, Vitamin C: 6.940799999999999, Linoleic Acid: 89.44575, Alpha-Linolenic Acid: 11.951039999999999, )
# Meal 1: Ketchup-braised meatballs and paprika (Energy: 102.465, Protein: 7.96325, Fat: 4.123200000000001, Carbohydrate: 7.7219, Total Dietary: 1.159, Calcium: 19.975, Iron: 0.67565, Sodium: 100.865, Vitamin A: 41.12916666835, Vitamin B1 (Thiamine): 0.200845, Vitamin B2 (Rivoflavin): 0.16317, Vitamin C: 11.077000000000002, Linoleic Acid: 1614.2765, Alpha-Linolenic Acid: 201.3916, )
# Please begin by phrasing your numeric answer as: "The meal plan is a X out of 10" and then explaining your rating.
#
# The meal plan is a 7 out of 10.
#
# The seasoned salad appears to be very healthy and provides a good source of calcium, iron, and vitamins A, B1, B2, and C. However, it lacks significant protein, which is important for muscle growth and repair.
#
# The ketchup-braised meatballs and paprika provide a good source of protein and some vitamins and minerals, but the ketchup may contain added sugars and sodium, which can contribute to health issues in excess amounts. Additionally, the meal plan should include some complex carbohydrates for sustained energy during physical activity.
#
# Overall, the meal plan has room for improvement in terms of balance and nutritional content, but it does show some good choices for essential nutrients.
# I am a 6ft tall 25 year old male, 168 pounds. I am very active. Please rate the following proposed meal plan on a scale of 1-10, where 1 is an unhealthy or unnatural meal plan and 10 is a perfect, balanced healthy meal plan:
# Meal 0: Seasoned salad with cabbage in soy paste (Energy: 22.115000000000002, Protein: 0.89915, Fat: 0.41678000000000004, Carbohydrate: 4.28053, Total Dietary: 0.9774999999999999, Calcium: 20.221999999999998, Iron: 0.2896000000000001, Sodium: 102.672, Vitamin A: 0.6118333331839999, Vitamin B1 (Thiamine): 0.029720000000000003, Vitamin B2 (Rivoflavin): 0.02663, Vitamin C: 6.940799999999999, Linoleic Acid: 89.44575, Alpha-Linolenic Acid: 11.951039999999999, )
# Meal 1: Ketchup-braised meatballs and paprika (Energy: 102.465, Protein: 7.96325, Fat: 4.123200000000001, Carbohydrate: 7.7219, Total Dietary: 1.159, Calcium: 19.975, Iron: 0.67565, Sodium: 100.865, Vitamin A: 41.12916666835, Vitamin B1 (Thiamine): 0.200845, Vitamin B2 (Rivoflavin): 0.16317, Vitamin C: 11.077000000000002, Linoleic Acid: 1614.2765, Alpha-Linolenic Acid: 201.3916, )
# Meal 2: Perilla seed korean-leek onion soup (Energy: 28.974, Protein: 2.22879, Fat: 1.33761, Carbohydrate: 2.45455, Total Dietary: 0.9269000000000001, Calcium: 58.669, Iron: 0.8508100000000001, Sodium: 75.026, Vitamin A: 0.83250000005, Vitamin B1 (Thiamine): 0.034919, Vitamin B2 (Rivoflavin): 0.036898, Vitamin C: 1.43393, Linoleic Acid: 158.89034, Alpha-Linolenic Acid: 743.1169000000001, )
# Please begin by phrasing your numeric answer as: "The meal plan is a X out of 10" and then explaining your rating.
#
# The meal plan is a 6 out of 10.
#
# The salad in Meal 0 is a good choice for a low-calorie and high fiber option, although it seems to be lacking in protein which is important for muscle building and repair.
#
# The meatballs in Meal 1 provide a good source of protein, but are quite high in sodium due to the ketchup. The paprika adds flavor and some beneficial antioxidants.
#
# The Korean-leek onion soup in Meal 2 is a good source of fiber and vitamin A, but again could benefit from more protein. The perilla seeds provide healthy fats which are important for overall health.
#
# Overall, the meal plan has some healthy components but could benefit from more balance with regards to macronutrients. It would be important to ensure that enough protein is consumed throughout the day to support an active lifestyle. Additionally, including more whole grains and fruits/vegetables could further improve the nutrient profile of the meals.
# I am a 6ft tall 25 year old male, 168 pounds. I am very active. Please rate the following proposed meal plan on a scale of 1-10, where 1 is an unhealthy or unnatural meal plan and 10 is a perfect, balanced healthy meal plan:
# Meal 0: Seasoned salad with cabbage in soy paste (Energy: 22.115000000000002, Protein: 0.89915, Fat: 0.41678000000000004, Carbohydrate: 4.28053, Total Dietary: 0.9774999999999999, Calcium: 20.221999999999998, Iron: 0.2896000000000001, Sodium: 102.672, Vitamin A: 0.6118333331839999, Vitamin B1 (Thiamine): 0.029720000000000003, Vitamin B2 (Rivoflavin): 0.02663, Vitamin C: 6.940799999999999, Linoleic Acid: 89.44575, Alpha-Linolenic Acid: 11.951039999999999, )
# Meal 1: Ketchup-braised meatballs and paprika (Energy: 102.465, Protein: 7.96325, Fat: 4.123200000000001, Carbohydrate: 7.7219, Total Dietary: 1.159, Calcium: 19.975, Iron: 0.67565, Sodium: 100.865, Vitamin A: 41.12916666835, Vitamin B1 (Thiamine): 0.200845, Vitamin B2 (Rivoflavin): 0.16317, Vitamin C: 11.077000000000002, Linoleic Acid: 1614.2765, Alpha-Linolenic Acid: 201.3916, )
# Meal 2: Perilla seed korean-leek onion soup (Energy: 28.974, Protein: 2.22879, Fat: 1.33761, Carbohydrate: 2.45455, Total Dietary: 0.9269000000000001, Calcium: 58.669, Iron: 0.8508100000000001, Sodium: 75.026, Vitamin A: 0.83250000005, Vitamin B1 (Thiamine): 0.034919, Vitamin B2 (Rivoflavin): 0.036898, Vitamin C: 1.43393, Linoleic Acid: 158.89034, Alpha-Linolenic Acid: 743.1169000000001, )
# Meal 3: Chicken seaweed soup (Energy: 41.885999999999996, Protein: 5.44196, Fat: 1.9190399999999999, Carbohydrate: 1.4697, Total Dietary: 1.0766, Calcium: 36.236000000000004, Iron: 0.43184, Sodium: 268.534, Vitamin A: 24.876250001005, Vitamin B1 (Thiamine): 0.040561, Vitamin B2 (Rivoflavin): 0.048082, Vitamin C: 0.040069999999999995, Linoleic Acid: 634.1332600000001, Alpha-Linolenic Acid: 23.36235, )
# Please begin by phrasing your numeric answer as: "The meal plan is a X out of 10" and then explaining your rating.
#
# The meal plan is a 7 out of 10.
#
# Overall, the meal plan includes a variety of nutrients from different food groups, such as vegetables, meat, and seeds. Meal 0 contains a good source of fiber, calcium, and vitamins A, B1, B2, and C. Meal 1 provides protein, iron, and vitamins A, B1, B2, and C. Meal 2 includes protein, calcium, iron, and vitamins A, B1, B2, and C, and meal 3 provides protein, calcium, iron, and vitamins A, B1, and B2.
#
# However, the meal plan may be lacking in carbohydrates and healthy fats. Only meal 1 includes a moderate amount of carbohydrates, while the other meals contain very low amounts. Additionally, while the omega-6 fatty acid linoleic acid is present in all meals, only meal 0 contains a small amount of omega-3 fatty acid alpha-linolenic acid.
#
# It is important to incorporate a balance of carbohydrates, proteins, and healthy fats in a meal plan that meets the individual's energy and nutrient needs.
# I am a 6ft tall 25 year old male, 168 pounds. I am very active. Please rate the following proposed meal plan on a scale of 1-10, where 1 is an unhealthy or unnatural meal plan and 10 is a perfect, balanced healthy meal plan:
# Meal 0: Seasoned salad with cabbage in soy paste (Energy: 22.115000000000002, Protein: 0.89915, Fat: 0.41678000000000004, Carbohydrate: 4.28053, Total Dietary: 0.9774999999999999, Calcium: 20.221999999999998, Iron: 0.2896000000000001, Sodium: 102.672, Vitamin A: 0.6118333331839999, Vitamin B1 (Thiamine): 0.029720000000000003, Vitamin B2 (Rivoflavin): 0.02663, Vitamin C: 6.940799999999999, Linoleic Acid: 89.44575, Alpha-Linolenic Acid: 11.951039999999999, )
# Meal 1: Ketchup-braised meatballs and paprika (Energy: 102.465, Protein: 7.96325, Fat: 4.123200000000001, Carbohydrate: 7.7219, Total Dietary: 1.159, Calcium: 19.975, Iron: 0.67565, Sodium: 100.865, Vitamin A: 41.12916666835, Vitamin B1 (Thiamine): 0.200845, Vitamin B2 (Rivoflavin): 0.16317, Vitamin C: 11.077000000000002, Linoleic Acid: 1614.2765, Alpha-Linolenic Acid: 201.3916, )
# Meal 8: seafood porridge (Energy: 124.55399999999999, Protein: 5.646, Fat: 1.54208, Carbohydrate: 20.84518, Total Dietary: 0.35000000000000003, Calcium: 13.846, Iron: 0.6599000000000002, Sodium: 117.586, Vitamin A: 24.211000001604003, Vitamin B1 (Thiamine): 0.068, Vitamin B2 (Rivoflavin): 0.024489999999999998, Vitamin C: 0.7004999999999999, Linoleic Acid: 505.45349999999996, Alpha-Linolenic Acid: 9.07934, )
# Meal 9: Braised white bait (Energy: 80.424, Protein: 9.23746, Fat: 3.791, Carbohydrate: 1.71517, Total Dietary: 0.0221, Calcium: 149.73700000000002, Iron: 0.52574, Sodium: 150.70799999999997, Vitamin A: 0.03533333335, Vitamin B1 (Thiamine): 0.028735, Vitamin B2 (Rivoflavin): 0.042182, Vitamin C: 0.55, Linoleic Acid: 1074.2883000000002, Alpha-Linolenic Acid: 131.85918, )
# Meal 10: Seasoned salad with chwinamul and perilla seed (Energy: 54.150000000000006, Protein: 1.7769, Fat: 3.317, Carbohydrate: 5.2924, Total Dietary: 2.356, Calcium: 59.989999999999995, Iron: 2.3963000000000005, Sodium: 97.75999999999999, Vitamin A: 67.24249998833999, Vitamin B1 (Thiamine): 0.03132, Vitamin B2 (Rivoflavin): 0.23060000000000003, Vitamin C: 4.5009999999999994, Linoleic Acid: 1021.5916, Alpha-Linolenic Acid: 817.1200000000001, )
# Meal 11: Braised quail eggs and paprika in ketchup (Energy: 61.183, Protein: 4.104830000000001, Fat: 3.02952, Carbohydrate: 4.03345, Total Dietary: 0.5793, Calcium: 23.848, Iron: 0.91832, Sodium: 91.71199999999999, Vitamin A: 51.0566666665, Vitamin B1 (Thiamine): 0.06376799999999999, Vitamin B2 (Rivoflavin): 0.19931600000000002, Vitamin C: 6.99386, Linoleic Acid: 355.90002999999996, Alpha-Linolenic Acid: 11.3958, )
# Please begin by phrasing your numeric answer as: "The meal plan is a X out of 10" and then explaining your rating.
#
# The meal plan is a 7 out of 10.
#
# Overall, this meal plan is fairly healthy and well-rounded. There is a good mix of protein, carbohydrates, and healthy fats. Additionally, there is a variety of vegetables and sources of micronutrients.
#
# However, there are a few areas where this meal plan could be improved. Firstly, some of the meals seem quite low in calories and may not be enough to sustain an active individual such as yourself. Secondly, some of the meals contain high levels of sodium which could be a concern for blood pressure. Finally, there are certain micronutrients that could be improved upon, such as vitamin C and calcium.
#
# Overall, this is a good starting point but there are some tweaks that could be made to improve it further.
# I am a 6ft tall 25 year old male, 168 pounds. I am very active. Please rate the following proposed meal plan on a scale of 1-10, where 1 is an unhealthy or unnatural meal plan and 10 is a perfect, balanced healthy meal plan:
# Meal 0: Seasoned salad with cabbage in soy paste (Energy: 22.115000000000002, Protein: 0.89915, Fat: 0.41678000000000004, Carbohydrate: 4.28053, Total Dietary: 0.9774999999999999, Calcium: 20.221999999999998, Iron: 0.2896000000000001, Sodium: 102.672, Vitamin A: 0.6118333331839999, Vitamin B1 (Thiamine): 0.029720000000000003, Vitamin B2 (Rivoflavin): 0.02663, Vitamin C: 6.940799999999999, Linoleic Acid: 89.44575, Alpha-Linolenic Acid: 11.951039999999999, )
# Meal 15: Stir-fried vegetables and eggs (Energy: 81.497, Protein: 5.3708, Fat: 4.9673, Carbohydrate: 3.416, Total Dietary: 0.5750000000000001, Calcium: 29.521000000000004, Iron: 0.9926999999999999, Sodium: 87.94300000000001, Vitamin A: 82.97766666854999, Vitamin B1 (Thiamine): 0.04481, Vitamin B2 (Rivoflavin): 0.20442, Vitamin C: 9.972999999999999, Linoleic Acid: 1462.1345, Alpha-Linolenic Acid: 145.7001, )
# Meal 16: Steamed rice with thistle and bean sprout + marinade sauce (Energy: 201.26, Protein: 5.846499999999999, Fat: 4.1811, Carbohydrate: 34.943599999999996, Total Dietary: 0.5840000000000001, Calcium: 129.88, Iron: 1.7445, Sodium: 147.44000000000003, Vitamin A: 116.38250001320999, Vitamin B1 (Thiamine): 0.29147, Vitamin B2 (Rivoflavin): 0.15681, Vitamin C: 5.414000000000001, Linoleic Acid: 940.1926, Alpha-Linolenic Acid: 1323.8899000000001, )
# Meal 17: Stir-fried broccoli and nuts (Energy: 61.959999999999994, Protein: 2.4909, Fat: 4.8221, Carbohydrate: 3.2281, Total Dietary: 1.775, Calcium: 25.0, Iron: 0.49119999999999997, Sodium: 49.059999999999995, Vitamin A: 6.6525, Vitamin B1 (Thiamine): 0.02283, Vitamin B2 (Rivoflavin): 0.11188000000000001, Vitamin C: 8.751, Linoleic Acid: 1884.4898, Alpha-Linolenic Acid: 151.4411, )
# Meal 18: chicken veggie porridge (Energy: 123.41399999999999, Protein: 5.3515, Fat: 1.5140799999999999, Carbohydrate: 20.90958, Total Dietary: 0.29100000000000004, Calcium: 5.886, Iron: 0.5501, Sodium: 78.896, Vitamin A: 21.614333334264, Vitamin B1 (Thiamine): 0.0926, Vitamin B2 (Rivoflavin): 0.04274, Vitamin C: 0.6756, Linoleic Acid: 503.19419999999997, Alpha-Linolenic Acid: 8.04234, )
# Please begin by phrasing your numeric answer as: "The meal plan is a X out of 10" and then explaining your rating.
#
# No response found, querying chatgpt...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[32], line 13
#       3 print(f'Output stored at: {log_dir}')
#       5 gpt_env.set_reward_weights(
#       6     coef_nutrition_lower=1,
#       7     coef_nutrition_upper=-1,
#    (...)
#      11     coef_carbon=3
#      12 )
# ---> 13 run_with_learning_algorithm(A2C, gpt_env, 1000, log_dir, num_meals=21, seed=0, n_eval_episodes=10, num_episodes=10)
#
# Cell In[27], line 136, in run_with_learning_algorithm(algorithm, env, num_timesteps, log_dir, num_meals, seed, print_before_after, plot, n_eval_episodes, num_episodes)
#     133     meal_sample(model, env)
#     134     print('\n')
# --> 136 model.learn(total_timesteps=num_timesteps, callback=callback)
#     137 reward_means, _ = evaluate_policy(model=model, env=env, n_eval_episodes=n_eval_episodes, render=False, return_episode_rewards=True, deterministic=False)
#     139 if print_before_after:
#
# File ~/opt/miniconda3/envs/new_rl/lib/python3.10/site-packages/stable_baselines3/a2c/a2c.py:193, in A2C.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     183 def learn(
#     184     self: SelfA2C,
#     185     total_timesteps: int,
#    (...)
#     190     progress_bar: bool = False,
#     191 ) -> SelfA2C:
# --> 193     return super().learn(
#     194         total_timesteps=total_timesteps,
#     195         callback=callback,
#     196         log_interval=log_interval,
#     197         tb_log_name=tb_log_name,
#     198         reset_num_timesteps=reset_num_timesteps,
#     199         progress_bar=progress_bar,
#     200     )
#
# File ~/opt/miniconda3/envs/new_rl/lib/python3.10/site-packages/stable_baselines3/common/on_policy_algorithm.py:248, in OnPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     244 callback.on_training_start(locals(), globals())
#     246 while self.num_timesteps < total_timesteps:
# --> 248     continue_training = self.collect_rollouts(self.env, callback, self.rollout_buffer, n_rollout_steps=self.n_steps)
#     250     if continue_training is False:
#     251         break
#
# File ~/opt/miniconda3/envs/new_rl/lib/python3.10/site-packages/stable_baselines3/common/on_policy_algorithm.py:175, in OnPolicyAlgorithm.collect_rollouts(self, env, callback, rollout_buffer, n_rollout_steps)
#     172 if isinstance(self.action_space, spaces.Box):
#     173     clipped_actions = np.clip(actions, self.action_space.low, self.action_space.high)
# --> 175 new_obs, rewards, dones, infos = env.step(clipped_actions)
#     177 self.num_timesteps += env.num_envs
#     179 # Give access to local variables
#
# File ~/opt/miniconda3/envs/new_rl/lib/python3.10/site-packages/stable_baselines3/common/vec_env/base_vec_env.py:163, in VecEnv.step(self, actions)
#     156 """
#     157 Step the environments with the given action
#     158
#     159 :param actions: the action
#     160 :return: observation, reward, done, information
#     161 """
#     162 self.step_async(actions)
# --> 163 return self.step_wait()
#
# File ~/opt/miniconda3/envs/new_rl/lib/python3.10/site-packages/stable_baselines3/common/vec_env/dummy_vec_env.py:54, in DummyVecEnv.step_wait(self)
#      52 def step_wait(self) -> VecEnvStepReturn:
#      53     for env_idx in range(self.num_envs):
# ---> 54         obs, self.buf_rews[env_idx], self.buf_dones[env_idx], self.buf_infos[env_idx] = self.envs[env_idx].step(
#      55             self.actions[env_idx]
#      56         )
#      57         if self.buf_dones[env_idx]:
#      58             # save final observation where user can get it, then reset
#      59             self.buf_infos[env_idx]["terminal_observation"] = obs
#
# File ~/opt/miniconda3/envs/new_rl/lib/python3.10/site-packages/stable_baselines3/common/monitor.py:94, in Monitor.step(self, action)
#      92 if self.needs_reset:
#      93     raise RuntimeError("Tried to step environment that needs reset")
# ---> 94 observation, reward, done, info = self.env.step(action)
#      95 self.rewards.append(reward)
#      96 if done:
#
# Cell In[27], line 384, in MealPlanningEnv.step(self, action)
#     380 info = {}
#     382 self.current_step += 1
# --> 384 reward = self._calculate_reward()
#     386 return self._next_observation(), reward, done, info
#
# Cell In[27], line 592, in GPTOnlyEnv._calculate_reward(self)
#     586 def _calculate_reward(self):
#     587     ## TODO: Replace with GPT Warmup
#     588     ## ALSO, prompt for carbon impact of meals as well
#     589     ## ALSO, add long term reward
#     590     # try:
# --> 592     meal_reward = self.meal_reward_from_chatgpt(verbose=True, person_type='Lucas') / 10
#     593     carbon_impact = np.mean(self.carbon_history) / 10
#     595     reward = float(
#     596         meal_reward +
#     597         self.reward_weights['coef_carbon'] * carbon_impact
#     598     ) / self.num_meals
#
# Cell In[27], line 572, in GPTOnlyEnv.meal_reward_from_chatgpt(self, verbose, person_type, save_response)
#     570 if verbose:
#     571     print('No response found, querying chatgpt...')
# --> 572 resp = openai.ChatCompletion.create(
#     573     model="gpt-3.5-turbo",
#     574     messages=[
#     575             {"role": "system", "content": "You are a helpful assistant and an expert in nutrition and meal planning."},
#     576             {"role": "user", "content": prompt},
#     577         ]
#     578 )
#     579 response = resp['choices'][0]['message']['content']
#     580 if save_response:
#
# File ~/opt/miniconda3/envs/new_rl/lib/python3.10/site-packages/openai/api_resources/chat_completion.py:25, in ChatCompletion.create(cls, *args, **kwargs)
#      23 while True:
#      24     try:
# ---> 25         return super().create(*args, **kwargs)
#      26     except TryAgain as e:
#      27         if timeout is not None and time.time() > start + timeout:
#
# File ~/opt/miniconda3/envs/new_rl/lib/python3.10/site-packages/openai/api_resources/abstract/engine_api_resource.py:153, in EngineAPIResource.create(cls, api_key, api_base, api_type, request_id, api_version, organization, **params)
#     127 @classmethod
#     128 def create(
#     129     cls,
#    (...)
#     136     **params,
#     137 ):
#     138     (
#     139         deployment_id,
#     140         engine,
#    (...)
#     150         api_key, api_base, api_type, api_version, organization, **params
#     151     )
# --> 153     response, _, api_key = requestor.request(
#     154         "post",
#     155         url,
#     156         params=params,
#     157         headers=headers,
#     158         stream=stream,
#     159         request_id=request_id,
#     160         request_timeout=request_timeout,
#     161     )
#     163     if stream:
#     164         # must be an iterator
#     165         assert not isinstance(response, OpenAIResponse)
#
# File ~/opt/miniconda3/envs/new_rl/lib/python3.10/site-packages/openai/api_requestor.py:216, in APIRequestor.request(self, method, url, params, headers, files, stream, request_id, request_timeout)
#     205 def request(
#     206     self,
#     207     method,
#    (...)
#     214     request_timeout: Optional[Union[float, Tuple[float, float]]] = None,
#     215 ) -> Tuple[Union[OpenAIResponse, Iterator[OpenAIResponse]], bool, str]:
# --> 216     result = self.request_raw(
#     217         method.lower(),
#     218         url,
#     219         params=params,
#     220         supplied_headers=headers,
#     221         files=files,
#     222         stream=stream,
#     223         request_id=request_id,
#     224         request_timeout=request_timeout,
#     225     )
#     226     resp, got_stream = self._interpret_response(result, stream)
#     227     return resp, got_stream, self.api_key
#
# File ~/opt/miniconda3/envs/new_rl/lib/python3.10/site-packages/openai/api_requestor.py:516, in APIRequestor.request_raw(self, method, url, params, supplied_headers, files, stream, request_id, request_timeout)
#     514     _thread_context.session = _make_session()
#     515 try:
# --> 516     result = _thread_context.session.request(
#     517         method,
#     518         abs_url,
#     519         headers=headers,
#     520         data=data,
#     521         files=files,
#     522         stream=stream,
#     523         timeout=request_timeout if request_timeout else TIMEOUT_SECS,
#     524         proxies=_thread_context.session.proxies,
#     525     )
#     526 except requests.exceptions.Timeout as e:
#     527     raise error.Timeout("Request timed out: {}".format(e)) from e
#
# File ~/opt/miniconda3/envs/new_rl/lib/python3.10/site-packages/requests/sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File ~/opt/miniconda3/envs/new_rl/lib/python3.10/site-packages/requests/sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File ~/opt/miniconda3/envs/new_rl/lib/python3.10/site-packages/requests/adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     487 try:
#     488     if not chunked:
# --> 489         resp = conn.urlopen(
#     490             method=request.method,
#     491             url=url,
#     492             body=request.body,
#     493             headers=request.headers,
#     494             redirect=False,
#     495             assert_same_host=False,
#     496             preload_content=False,
#     497             decode_content=False,
#     498             retries=self.max_retries,
#     499             timeout=timeout,
#     500         )
#     502     # Send the request.
#     503     else:
#     504         if hasattr(conn, "proxy_pool"):
#
# File ~/opt/miniconda3/envs/new_rl/lib/python3.10/site-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File ~/opt/miniconda3/envs/new_rl/lib/python3.10/site-packages/urllib3/connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444             httplib_response = conn.getresponse()
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~/opt/miniconda3/envs/new_rl/lib/python3.10/site-packages/urllib3/connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     441 except TypeError:
#     442     # Python 3
#     443     try:
# --> 444         httplib_response = conn.getresponse()
#     445     except BaseException as e:
#     446         # Remove the TypeError from the exception chain in
#     447         # Python 3 (including for exceptions like SystemExit).
#     448         # Otherwise it looks like a bug in the code.
#     449         six.raise_from(e, None)
#
# File ~/opt/miniconda3/envs/new_rl/lib/python3.10/http/client.py:1374, in HTTPConnection.getresponse(self)
#    1372 try:
#    1373     try:
# -> 1374         response.begin()
#    1375     except ConnectionError:
#    1376         self.close()
#
# File ~/opt/miniconda3/envs/new_rl/lib/python3.10/http/client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File ~/opt/miniconda3/envs/new_rl/lib/python3.10/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File ~/opt/miniconda3/envs/new_rl/lib/python3.10/socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# File ~/opt/miniconda3/envs/new_rl/lib/python3.10/ssl.py:1274, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1270     if flags != 0:
#    1271         raise ValueError(
#    1272           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1273           self.__class__)
# -> 1274     return self.read(nbytes, buffer)
#    1275 else:
#    1276     return super().recv_into(buffer, nbytes, flags)
#
# File ~/opt/miniconda3/envs/new_rl/lib/python3.10/ssl.py:1130, in SSLSocket.read(self, len, buffer)
#    1128 try:
#    1129     if buffer is not None:
# -> 1130         return self._sslobj.read(len, buffer)
#    1131     else:
#    1132         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
num_meals = 21
gpt_env = GPTOnlyEnv(possible_meals=possible_meals, meal_categories=meal_categories, nutrition_data=nutrition_data, carbon_data=carbon_data, num_meals=num_meals)

# %%
log_dir = f"./tmp/gym/{time.strftime('%Y%m%d-%H%M%S')}"
os.makedirs(log_dir, exist_ok=False)
print(f'Output stored at: {log_dir}')

gpt_env.set_reward_weights(
    coef_nutrition_lower=1,
    coef_nutrition_upper=-1,
    coef_sequence_entropy=0,
    coef_repetitions=0,
    coef_overall_entropy=0,
    coef_carbon=3
)
run_with_learning_algorithm(DQN, gpt_env, 10, log_dir, num_meals=21, seed=0)
